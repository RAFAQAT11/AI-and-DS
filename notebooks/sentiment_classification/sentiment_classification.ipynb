# %%
with open('data/reviews.txt','r') as file:
    reviews = list(map(lambda x:x[:-1],file.readlines()))
with open ('data/labels.txt') as file:
    labels = list(map(lambda x:x[:-1].upper(),file.readlines()))

# %%
import numpy as np
l = np.array(labels)
count = {"POSITIVE":0,"NEGATIVE":0}
for w in l:
    if w =="POSITIVE":
        count[w] +=1
    else: count[w] +=1
count
# Out:
# {'POSITIVE': 12500, 'NEGATIVE': 12500}

# %%
from collections import Counter
from spacy.lang.en.stop_words import STOP_WORDS

positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()
pos_neg_ratios = Counter()

for i in range(len(reviews)):
    if(labels[i] == 'POSITIVE'):
        for word in reviews[i].split(" "):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1
            
rm_words = 100

for term,cnt in list(total_counts.most_common()):
    if(cnt > rm_words):
        pos_neg_ratio = np.log(positive_counts[term] / float(negative_counts[term]+1))
        pos_neg_ratios[term] = pos_neg_ratio
        
new_vocab = []
for word,cnt in total_counts.most_common():
    if cnt>rm_words and word not in (' ,.!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n'+" ".join(STOP_WORDS)):
        new_vocab.append(word)

# %%
len(reviews)
# Out:
# 25000

# %%
new_vocab
# Out:
# ['br',
#  'movie',
#  'film',
#  'like',
#  'good',
#  'story',
#  'bad',
#  'people',
#  'great',
#  'movies',
#  'think',
#  'characters',
#  'character',
#  'watch',
#  'films',
#  'seen',
#  'life',
#  'plot',
#  'acting',
#  'love',
#  'little',
#  'best',
#  'know',
#  'better',
#  'end',
#  'scene',
#  'scenes',
#  'watching',
#  'doesn',
#  'old',
#  'years',
#  'actors',
#  'director',
#  'work',
#  'didn',
#  'new',
#  'funny',
#  'actually',
#  'makes',
#  'look',
#  'find',
#  'going',
#  'lot',
#  'world',
#  'cast',
#  'want',
#  'things',
#  'pretty',
#  'young',
#  'horror',
#  'got',
#  'fact',
#  'big',
#  'thought',
#  'series',
#  'original',
#  'action',
#  'right',
#  'comedy',
#  'point',
#  'gets',
#  'family',
#  'role',
#  'isn',
#  'saw',
#  'interesting',
#  'bit',
#  'music',
#  'guy',
#  'script',
#  'far',
#  'making',
#  'minutes',
#  'feel',
#  'performance',
#  'girl',
#  'probably',
#  'woman',
#  'kind',
#  'tv',
#  'away',
#  'day',
#  'worst',
#  'fun',
#  'sure',
#  'hard',
#  'played',
#  'found',
#  'having',
#  'especially',
#  'course',
#  'believe',
#  'screen',
#  'looking',
#  'trying',
#  'set',
#  'goes',
#  'book',
#  'looks',
#  'place',
#  'actor',
#  'different',
#  'money',
#  'year',
#  'ending',
#  'dvd',
#  'maybe',
#  'let',
#  'true',
#  'sense',
#  'reason',
#  'wasn',
#  'shows',
#  'worth',
#  'job',
#  'main',
#  'play',
#  'watched',
#  'american',
#  'plays',
#  'john',
#  'effects',
#  'later',
#  'audience',
#  'said',
#  'takes',
#  'instead',
#  'house',
#  'beautiful',
#  'night',
#  'high',
#  'version',
#  'wife',
#  'left',
#  'father',
#  'special',
#  'seeing',
#  'half',
#  'star',
#  'excellent',
#  'shot',
#  'idea',
#  'black',
#  'nice',
#  'mind',
#  'simply',
#  'second',
#  'fan',
#  'men',
#  'death',
#  'hollywood',
#  'poor',
#  'help',
#  'completely',
#  'home',
#  'dead',
#  'line',
#  'short',
#  'given',
#  'kids',
#  'budget',
#  'try',
#  'classic',
#  'wrong',
#  'performances',
#  'women',
#  'enjoy',
#  'boring',
#  'need',
#  'rest',
#  'friends',
#  'production',
#  'camera',
#  'truly',
#  'video',
#  'awful',
#  'couple',
#  'tell',
#  'remember',
#  'stupid',
#  'start',
#  'stars',
#  'sex',
#  'won',
#  'recommend',
#  'moments',
#  'school',
#  'episode',
#  'wonderful',
#  'small',
#  'face',
#  'understand',
#  'terrible',
#  'playing',
#  'getting',
#  'written',
#  'early',
#  'style',
#  'perfect',
#  'human',
#  'person',
#  'definitely',
#  'gives',
#  'boy',
#  'lines',
#  'lost',
#  'live',
#  'dialogue',
#  'head',
#  'piece',
#  'finally',
#  'case',
#  'yes',
#  'felt',
#  'mother',
#  'liked',
#  'supposed',
#  'children',
#  'title',
#  'couldn',
#  'cinema',
#  'white',
#  'absolutely',
#  'picture',
#  'sort',
#  'worse',
#  'certainly',
#  'entire',
#  'waste',
#  'killer',
#  'problem',
#  'oh',
#  'mr',
#  'hope',
#  'evil',
#  'entertaining',
#  'friend',
#  'overall',
#  'called',
#  'based',
#  'loved',
#  'fans',
#  'drama',
#  'beginning',
#  'lives',
#  'direction',
#  'care',
#  'dark',
#  'laugh',
#  'example',
#  'despite',
#  'turn',
#  'son',
#  'unfortunately',
#  'wanted',
#  'michael',
#  'history',
#  'heart',
#  'final',
#  'fine',
#  'child',
#  'sound',
#  'amazing',
#  'guess',
#  'lead',
#  'humor',
#  'totally',
#  'writing',
#  'guys',
#  'quality',
#  'close',
#  'wants',
#  'game',
#  'works',
#  'town',
#  'tries',
#  'days',
#  'past',
#  'viewer',
#  'able',
#  'flick',
#  'genre',
#  'turns',
#  'act',
#  'enjoyed',
#  'today',
#  'kill',
#  'favorite',
#  'car',
#  'soon',
#  'starts',
#  'run',
#  'actress',
#  'gave',
#  'eyes',
#  'late',
#  'girls',
#  'etc',
#  'god',
#  'directed',
#  'horrible',
#  'kid',
#  'city',
#  'brilliant',
#  'parts',
#  'hour',
#  'blood',
#  'stories',
#  'thinking',
#  'expect',
#  'stuff',
#  'obviously',
#  'decent',
#  'voice',
#  'writer',
#  'fight',
#  'highly',
#  'feeling',
#  'daughter',
#  'slow',
#  'matter',
#  'type',
#  'age',
#  'roles',
#  'moment',
#  'killed',
#  'heard',
#  'says',
#  'leave',
#  'brother',
#  'took',
#  'strong',
#  'police',
#  'violence',
#  'stop',
#  'happens',
#  'known',
#  'particularly',
#  'involved',
#  'happened',
#  'chance',
#  'extremely',
#  'james',
#  'obvious',
#  'murder',
#  'told',
#  'living',
#  'experience',
#  'lack',
#  'hero',
#  'wouldn',
#  'including',
#  'attempt',
#  'happen',
#  'gore',
#  'crap',
#  'wonder',
#  'cut',
#  'group',
#  'complete',
#  'ago',
#  'interest',
#  'score',
#  'husband',
#  'hell',
#  'save',
#  'david',
#  'simple',
#  'ok',
#  'looked',
#  'song',
#  'career',
#  'number',
#  'seriously',
#  'possible',
#  'annoying',
#  'sad',
#  'exactly',
#  'shown',
#  'king',
#  'running',
#  'musical',
#  'scary',
#  'reality',
#  'taken',
#  'released',
#  'cinematography',
#  'english',
#  'ends',
#  'hours',
#  'usually',
#  'opening',
#  'jokes',
#  'light',
#  'hilarious',
#  'cool',
#  'somewhat',
#  'usual',
#  'happy',
#  'relationship',
#  'ridiculous',
#  'view',
#  'level',
#  'started',
#  'change',
#  'opinion',
#  'wish',
#  'novel',
#  'middle',
#  'talking',
#  'taking',
#  'documentary',
#  'ones',
#  'robert',
#  'order',
#  'shots',
#  'finds',
#  'power',
#  'saying',
#  'female',
#  'huge',
#  'room',
#  'episodes',
#  'country',
#  'talent',
#  'important',
#  'rating',
#  'modern',
#  'earth',
#  'strange',
#  'major',
#  'word',
#  'turned',
#  'jack',
#  'apparently',
#  'single',
#  'disappointed',
#  'events',
#  'songs',
#  'basically',
#  'attention',
#  'television',
#  'comic',
#  'knows',
#  'future',
#  'supporting',
#  'clearly',
#  'knew',
#  'british',
#  'fast',
#  'thriller',
#  'paul',
#  'class',
#  'easily',
#  'cheap',
#  'silly',
#  'problems',
#  'aren',
#  'words',
#  'miss',
#  'tells',
#  'entertainment',
#  'local',
#  'sequence',
#  'rock',
#  'bring',
#  'george',
#  'straight',
#  'oscar',
#  'romantic',
#  'predictable',
#  'moving',
#  'sets',
#  'similar',
#  'review',
#  'eye',
#  'falls',
#  'mystery',
#  'lady',
#  'richard',
#  'talk',
#  'enjoyable',
#  'appears',
#  'needs',
#  'giving',
#  'message',
#  'theater',
#  'animation',
#  'near',
#  'team',
#  'sequel',
#  'sister',
#  'dull',
#  'theme',
#  'stand',
#  'nearly',
#  'lee',
#  'bunch',
#  'points',
#  'mention',
#  'add',
#  'york',
#  'feels',
#  'haven',
#  'release',
#  'storyline',
#  'easy',
#  'surprised',
#  'named',
#  'fantastic',
#  'lots',
#  'begins',
#  'working',
#  'die',
#  'actual',
#  'effort',
#  'feature',
#  'tale',
#  'french',
#  'minute',
#  'stay',
#  'follow',
#  'viewers',
#  'clear',
#  'elements',
#  'comments',
#  'typical',
#  'editing',
#  'avoid',
#  'showing',
#  'tried',
#  'season',
#  'famous',
#  'sorry',
#  'fall',
#  'dialog',
#  'check',
#  'peter',
#  'period',
#  'certain',
#  'general',
#  'filmed',
#  'buy',
#  'soundtrack',
#  'parents',
#  'weak',
#  'means',
#  'material',
#  'realistic',
#  'figure',
#  'doubt',
#  'crime',
#  'space',
#  'gone',
#  'disney',
#  'kept',
#  'viewing',
#  'leads',
#  'greatest',
#  'dance',
#  'lame',
#  'suspense',
#  'zombie',
#  'brought',
#  'imagine',
#  'atmosphere',
#  'hear',
#  'particular',
#  'america',
#  'sequences',
#  'rent',
#  'eventually',
#  'average',
#  'learn',
#  'wait',
#  'forget',
#  'reviews',
#  'deal',
#  'note',
#  'japanese',
#  'surprise',
#  'stage',
#  'sexual',
#  'poorly',
#  'okay',
#  'premise',
#  'believable',
#  'sit',
#  'nature',
#  'possibly',
#  'subject',
#  'decided',
#  'expected',
#  'truth',
#  'imdb',
#  'street',
#  'free',
#  'screenplay',
#  'difficult',
#  'romance',
#  'killing',
#  'baby',
#  'joe',
#  'dog',
#  'hot',
#  'reading',
#  'question',
#  'needed',
#  'leaves',
#  'begin',
#  'meets',
#  'society',
#  'directors',
#  'credits',
#  'shame',
#  'superb',
#  'write',
#  'situation',
#  'meet',
#  'dramatic',
#  'male',
#  'memorable',
#  'open',
#  'badly',
#  'earlier',
#  'writers',
#  'weird',
#  'dream',
#  'forced',
#  'acted',
#  'sci',
#  'crazy',
#  'laughs',
#  'emotional',
#  'jane',
#  'older',
#  'monster',
#  'beauty',
#  'realize',
#  'comment',
#  'deep',
#  'footage',
#  'forward',
#  'interested',
#  'ask',
#  'fantasy',
#  'plus',
#  'sounds',
#  'mark',
#  'directing',
#  'keeps',
#  'development',
#  'features',
#  'mess',
#  'air',
#  'quickly',
#  'creepy',
#  'box',
#  'girlfriend',
#  'perfectly',
#  'worked',
#  'cheesy',
#  'unique',
#  'setting',
#  'effect',
#  'plenty',
#  'total',
#  'hands',
#  'bill',
#  'result',
#  'previous',
#  'fire',
#  'brings',
#  'personal',
#  'incredibly',
#  'rate',
#  'business',
#  'joke',
#  'doctor',
#  'casting',
#  'return',
#  'apart',
#  'christmas',
#  'leading',
#  'admit',
#  'powerful',
#  'appear',
#  'cop',
#  'background',
#  'boys',
#  'ben',
#  'present',
#  'meant',
#  'telling',
#  'battle',
#  'hardly',
#  'break',
#  'create',
#  'masterpiece',
#  'potential',
#  'secret',
#  'pay',
#  'political',
#  'gay',
#  'fighting',
#  'dumb',
#  'fails',
#  'twist',
#  'portrayed',
#  'inside',
#  'villain',
#  'western',
#  'nudity',
#  'outside',
#  'reasons',
#  'william',
#  'ideas',
#  'match',
#  'missing',
#  'deserves',
#  'married',
#  'expecting',
#  'rich',
#  'fairly',
#  'talented',
#  'list',
#  'success',
#  'unlike',
#  'scott',
#  'attempts',
#  'manages',
#  'remake',
#  'odd',
#  'social',
#  'cute',
#  'recently',
#  'flat',
#  'spoilers',
#  'copy',
#  'wrote',
#  'sadly',
#  'agree',
#  'sweet',
#  'cold',
#  'crew',
#  'plain',
#  'office',
#  'mary',
#  'filmmakers',
#  'following',
#  'missed',
#  'public',
#  'mentioned',
#  'incredible',
#  'gun',
#  'pure',
#  'wasted',
#  'brothers',
#  'ended',
#  'large',
#  'produced',
#  'caught',
#  'revenge',
#  'members',
#  'pace',
#  'filled',
#  'popular',
#  'party',
#  'waiting',
#  'science',
#  'water',
#  'cat',
#  'decides',
#  'cartoon',
#  'hold',
#  'considering',
#  'spirit',
#  'tension',
#  'created',
#  'slightly',
#  'uses',
#  'fear',
#  'convincing',
#  'compared',
#  'familiar',
#  'suddenly',
#  'escape',
#  'spent',
#  'sees',
#  'island',
#  'intelligent',
#  'clever',
#  'state',
#  'entirely',
#  'dancing',
#  'language',
#  'bored',
#  'moves',
#  'credit',
#  'choice',
#  'kills',
#  'band',
#  'laughing',
#  'century',
#  'italian',
#  'cover',
#  'value',
#  'violent',
#  'visual',
#  'successful',
#  'tony',
#  'speak',
#  'trouble',
#  'ultimately',
#  'basic',
#  'concept',
#  'singing',
#  'store',
#  'positive',
#  'studio',
#  'zombies',
#  'german',
#  'animated',
#  'biggest',
#  'company',
#  'exciting',
#  'force',
#  'runs',
#  'consider',
#  'died',
#  'effective',
#  'control',
#  'depth',
#  'recent',
#  'adult',
#  'walk',
#  'adventure',
#  'amusing',
#  'common',
#  'law',
#  'portrayal',
#  'spend',
#  'focus',
#  'appreciate',
#  'rated',
#  'pointless',
#  'books',
#  'hair',
#  'trash',
#  'solid',
#  'younger',
#  'planet',
#  'impressive',
#  'super',
#  'tone',
#  'bizarre',
#  'respect',
#  'follows',
#  'college',
#  'culture',
#  'van',
#  'impossible',
#  'smith',
#  'prison',
#  'trip',
#  'heavy',
#  'project',
#  'producers',
#  'dad',
#  'win',
#  'weren',
#  'slasher',
#  'makers',
#  'chemistry',
#  'recommended',
#  'conclusion',
#  'showed',
#  'fit',
#  'sick',
#  'situations',
#  'jim',
#  'starring',
#  'accent',
#  'disturbing',
#  'awesome',
#  'considered',
#  'ghost',
#  'changed',
#  'steve',
#  'failed',
#  'cult',
#  'post',
#  'barely',
#  'decide',
#  'honest',
#  'leaving',
#  'questions',
#  'anti',
#  'shooting',
#  'tough',
#  'longer',
#  'audiences',
#  'fiction',
#  'west',
#  'brain',
#  'aside',
#  'fake',
#  'meaning',
#  'touch',
#  'south',
#  'thanks',
#  'images',
#  'charming',
#  'computer',
#  'magic',
#  'pathetic',
#  'stewart',
#  'generally',
#  'stick',
#  'literally',
#  'values',
#  'likes',
#  'surprisingly',
#  'alive',
#  'involving',
#  'natural',
#  'camp',
#  'immediately',
#  'yeah',
#  'military',
#  'harry',
#  'grade',
#  'detective',
#  'shoot',
#  'garbage',
#  'london',
#  'week',
#  'bought',
#  'frank',
#  'normal',
#  'aspect',
#  'fair',
#  'honestly',
#  'pictures',
#  'ability',
#  'utterly',
#  'adaptation',
#  'master',
#  'army',
#  'genius',
#  'pick',
#  'sitting',
#  'appearance',
#  'explain',
#  'glad',
#  'motion',
#  'attack',
#  'standard',
#  'drive',
#  'appeal',
#  'catch',
#  'personally',
#  'knowing',
#  'sexy',
#  'channel',
#  'rare',
#  'edge',
#  'humour',
#  'added',
#  'thank',
#  'comedies',
#  'walking',
#  'charlie',
#  'journey',
#  'silent',
#  'purpose',
#  'remains',
#  'chase',
#  'loud',
#  'naked',
#  'twists',
#  'taste',
#  'thinks',
#  'producer',
#  'beautifully',
#  'dreams',
#  'road',
#  'touching',
#  'date',
#  'unbelievable',
#  'subtle',
#  'terrific',
#  'terms',
#  'wow',
#  'equally',
#  'mood',
#  'club',
#  'wild',
#  'door',
#  'blue',
#  ...]

# %%
vocab = set(total_counts)
vocab_size = len(vocab)
word_index={word:index for index,word in enumerate(vocab)}

# %%
len(word_index)
vocab_size
# Out:
# 74074

# %%
def getFeatures(reviews=reviews):
    feature_size = np.zeros((1,vocab_size))
    features = []
    for review in reviews:
        feature_size *= 0
        for word in review:
            if word in word_index.keys():
                feature_size[0][word_index[word]] = 1
        features.append(feature_size[0])
    return features
def getTargets(labels=labels):
    return [ 1 if label == "POSITIVE" else 0 for label in labels]

# %%
features = np.array(getFeatures(reviews[:500]))
targets = np.array(getTargets(labels[:500]))

# %%
import time
import sys
import numpy as np

class Network:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1,epoch=1,load_model=False):
        np.random.seed(1)
        self.epoch = epoch
        self.pre_process_data(reviews, labels)
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate,load_model)

    def pre_process_data(self, reviews, labels):
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
                
        self.review_vocab = list(review_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i

    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate,load_model=False):
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        self.learning_rate = learning_rate
        if load_model:
            self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
            self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5,(self.hidden_nodes, self.output_nodes))
        else:
            self.load()
        self.layer_1 = np.zeros((1,hidden_nodes))
    
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews_raw, training_labels):
        assert self.epoch >= 1
        training_reviews = list()
        for review in training_reviews_raw:
            indices = set()
            for word in review.split(" "):
                if(word in self.word2index.keys()):
                    indices.add(self.word2index[word])
            training_reviews.append(list(indices))
        assert(len(training_reviews) == len(training_labels))
        correct_so_far = 0
        start = time.time()

        for _ in range(self.epoch):
            for i in range(len(training_reviews)):

                review = training_reviews[i]
                label = training_labels[i]

                # Hidden layer
                self.layer_1 *= 0
                for index in review:
                    self.layer_1 += self.weights_0_1[index]

                # Output layer
                layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))            

                # Output error
                layer_2_error = layer_2 - self.get_target_for_label(label) 
                layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

                # Backpropagated error
                layer_1_error = layer_2_delta.dot(self.weights_1_2.T) 
                layer_1_delta = layer_1_error 
                self.weights_1_2 -= self.layer_1.T.dot(layer_2_delta) * self.learning_rate 
                for index in review:
                    self.weights_0_1[index] -= layer_1_delta[0] * self.learning_rate 
                if(layer_2 >= 0.5 and label == 'POSITIVE'):
                    correct_so_far += 1
                elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                    correct_so_far += 1
                elapsed_time = float(time.time() - start)
                reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0

                print("Progress:" + str(100 * i/float(len(training_reviews)))[:4] 
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] 
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) 
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%",end="\r",flush=True)
            print("")
            correct_so_far = 0
    def test(self, testing_reviews, testing_labels):
        correct = 0
        start = time.time() 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            print("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] 
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] 
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) 
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%",end="\r",flush=True)
    
    def run(self, review):
        self.layer_1 *= 0
        unique_indices = set()
        for word in review.lower().split(" "):
            if word in self.word2index.keys():
                unique_indices.add(self.word2index[word])
        for index in unique_indices:
            self.layer_1 += self.weights_0_1[index]
        layer_2 = self.sigmoid(self.layer_1.dot(self.weights_1_2))
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"
    def save(self):
        np.savetxt("weights/w01.txt",self.weights_0_1)
        np.savetxt("weights/w12.txt",self.weights_1_2)
    def load(self):
        self.weights_0_1 = np.loadtxt("weights/w01.txt",delimiter=" ")
        self.weights_1_2 = np.loadtxt("weights/w12.txt",delimiter=" ",ndmin=2)

# %%
ml = Network(reviews[:-1000],labels[:-1000], learning_rate=0.001,load_model=True,epoch=1)
ml.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:99.9% Speed(reviews/sec):849.2 #Correct:20173 #Trained:24000 Training Accuracy:84.0%
# Progress:99.9% Speed(reviews/sec):425.2 #Correct:21304 #Trained:24000 Training Accuracy:88.7%
# Progress:99.9% Speed(reviews/sec):281.4 #Correct:21714 #Trained:24000 Training Accuracy:90.4%
# Progress:99.9% Speed(reviews/sec):211.0 #Correct:21970 #Trained:24000 Training Accuracy:91.5%

# %%
ml.save()

# %%
ml.test(reviews[1000:],labels[1000:])
# Out:
# Progress:11.9% Speed(reviews/sec):1058. #Correct:2660 #Tested:2868 Testing Accuracy:92.7%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progress:27.3% Speed(reviews/sec):1089. #Correct:6074 #Tested:6569 Testing Accuracy:92.4%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progress:43.0% Speed(reviews/sec):1080. #Correct:9534 #Tested:10321 Testing Accuracy:92.3%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progress:58.5% Speed(reviews/sec):1092. #Correct:12975 #Tested:14046 Testing Accuracy:92.3%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progress:74.5% Speed(reviews/sec):1102. #Correct:16549 #Tested:17882 Testing Accuracy:92.5%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progress:90.9% Speed(reviews/sec):1107. #Correct:20224 #Tested:21819 Testing Accuracy:92.6%
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Progress:99.9% Speed(reviews/sec):1105. #Correct:22207 #Tested:24000 Testing Accuracy:92.5%

# %%
ml.test(np.array(["not good","it was awesome movie"]),np.array(["NEGATIVE","POSITIVE"]))
# Out:
# Progress:50.0% Speed(reviews/sec):1026. #Correct:2 #Tested:2 Testing Accuracy:100.%

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
tsne2d = tsne.fit_transform(ml.weights_0_1)
ml.word2index.keys()
# Out:
# dict_keys(['', 'excrements', 'cratchitt', 'cram', 'spelled', 'rcc', 'demanded', 'animating', 'stall', 'mahin', 'livery', 'gaddis', 'letts', 'radlitch', 'apperance', 'jungian', 'forry', 'headaches', 'talkd', 'bagging', 'ota', 'perfetta', 'slauther', 'parenthood', 'incher', 'premonition', 'gendarme', 'valderamma', 'yevgeniya', 'mended', 'groupie', 'radziwill', 'divagations', 'thst', 'bookended', 'splice', 'slowness', 'sunken', 'kershner', 'ooh', 'pyare', 'nikkhil', 'bantering', 'collectible', 'colico', 'contextsnamely', 'drek', 'drss', 'mecha', 'invulnerable', 'personia', 'duke', 'tronje', 'kmc', 'inheritors', 'cipher', 'former', 'filmsadly', 'surefire', 'russborrough', 'wobbly', 'multy', 'pinning', 'ap', 'dalla', 'cripes', 'goobacks', 'seductress', 'misconceived', 'phenoms', 'respect', 'pervasive', 'morals', 'padget', 'stalky', 'renews', 'prolo', 'pioneered', 'bosnians', 'appereantly', 'sensationalist', 'mafia', 'universial', 'cabal', 'mysore', 'ownership', 'helpfuls', 'spartan', 'comraderie', 'pialat', 'vv', 'arminian', 'spitied', 'conniption', 'emmannuelle', 'nachtmusik', 'crashing', 'strongpoints', 'opulence', 'statement', 'daneliucs', 'tampering', 'arisen', 'woebegone', 'scrape', 'cgiwhich', 'brilliantly', 'gentility', 'fractured', 'stassard', 'croons', 'jumpedtheshark', 'compensations', 'dodgy', 'lifelong', 'thre', 'blackmailing', 'plumber', 'armor', 'puss', 'chant', 'nellie', 'voorhess', 'watterman', 'motorbikes', 'daslow', 'unbreakable', 'labourer', 'solondz', 'beer', 'ladykillers', 'binoche', 'scarecreow', 'villaronga', 'pelting', 'lol', 'cannabalistic', 'ball', 'ruffled', 'mercenary', 'glovers', 'bungy', 'alladin', 'steerage', 'offenders', 'hamm', 'windmills', 'autre', 'hooligan', 'mote', 'fiving', 'unbuckles', 'lipsticked', 'perversity', 'wopat', 'hogie', 'idealology', 'undergone', 'symbolize', 'filmrolls', 'agonized', 'gon', 'firetrap', 'harper', 'reforms', 'evening', 'discerned', 'surnamed', 'mounting', 'obnoxious', 'bothersome', 'electrifyingly', 'songmaking', 'elusiveness', 'dominque', 'brands', 'criminologist', 'turquistan', 'mesmeric', 'teensploitation', 'coiffure', 'twelve', 'jive', 'kindegarden', 'lrner', 'avalanche', 'wooh', 'balled', 'sebastian', 'ferocious', 'blandest', 'assassain', 'jampacked', 'zag', 'interface', 'gutenberg', 'endor', 'parrot', 'hays', 'ironed', 'expertise', 'sabella', 'flynnish', 'attonment', 'unanimousness', 'glumly', 'pitzalis', 'natwick', 'impetuous', 'handedness', 'genova', 'agatha', 'distributing', 'thermostat', 'adventist', 'league', 'aha', 'fitting', 'multiethnical', 'bonita', 'fearful', 'hatted', 'info', 'gulping', 'yanno', 'okuhara', 'dispersement', 'minna', 'memory', 'quibbling', 'greg', 'sleeveless', 'social', 'nutjobseen', 'lorica', 'sainthood', 'rempit', 'fastforward', 'estrange', 'innovating', 'unbowed', 'time', 'blackmailed', 'kappa', 'repayed', 'contractual', 'toulouse', 'filmically', 'gogo', 'repelling', 'honestly', 'sanitizes', 'feminist', 'apron', 'bittorrent', 'seniority', 'cumparsita', 'judd', 'buyer', 'braggart', 'blom', 'cobern', 'commercisliation', 'poppa', 'carto', 'flutters', 'overly', 'hobart', 'faltermeyer', 'seseme', 'oafs', 'playthings', 'adr', 'zaniness', 'feared', 'sequitur', 'narration', 'bhoomika', 'germaine', 'vaporising', 'solutions', 'bllsosopher', 'haje', 'stearns', 'hauteur', 'taxpayers', 'motoring', 'presence', 'nipar', 'factors', 'hyodo', 'stymie', 'salton', 'thorp', 'antonius', 'jutras', 'yelchin', 'ce', 'scouts', 'chabrol', 'woody', 'rashomon', 'cyrano', 'conferences', 'poly', 'amita', 'sycophant', 'indicating', 'escaped', 'bizarrely', 'payed', 'halleck', 'planetoids', 'herbut', 'represented', 'apallingly', 'hellbreeder', 'beepingmary', 'subzero', 'snarls', 'stripclub', 'coleen', 'partnering', 'shears', 'mendacious', 'plagiary', 'literates', 'delinquent', 'resistible', 'aviation', 'knox', 'kasugi', 'subdivisions', 'anderson', 'whately', 'endowment', 'mariette', 'gottowt', 'reproductive', 'quirkiness', 'reincarnation', 'paige', 'shriners', 'edyar ...

# %%
np.savetxt("weights/tsne.txt",tsne2d)
# Out:
# ['',
#  'excrements',
#  'cratchitt',
#  'cram',
#  'spelled',
#  'rcc',
#  'demanded',
#  'animating',
#  'stall',
#  'mahin',
#  'livery',
#  'gaddis',
#  'letts',
#  'radlitch',
#  'apperance',
#  'jungian',
#  'forry',
#  'headaches',
#  'talkd',
#  'bagging',
#  'ota',
#  'perfetta',
#  'slauther',
#  'parenthood',
#  'incher',
#  'premonition',
#  'gendarme',
#  'valderamma',
#  'yevgeniya',
#  'mended',
#  'groupie',
#  'radziwill',
#  'divagations',
#  'thst',
#  'bookended',
#  'splice',
#  'slowness',
#  'sunken',
#  'kershner',
#  'ooh',
#  'pyare',
#  'nikkhil',
#  'bantering',
#  'collectible',
#  'colico',
#  'contextsnamely',
#  'drek',
#  'drss',
#  'mecha',
#  'invulnerable',
#  'personia',
#  'duke',
#  'tronje',
#  'kmc',
#  'inheritors',
#  'cipher',
#  'former',
#  'filmsadly',
#  'surefire',
#  'russborrough',
#  'wobbly',
#  'multy',
#  'pinning',
#  'ap',
#  'dalla',
#  'cripes',
#  'goobacks',
#  'seductress',
#  'misconceived',
#  'phenoms',
#  'respect',
#  'pervasive',
#  'morals',
#  'padget',
#  'stalky',
#  'renews',
#  'prolo',
#  'pioneered',
#  'bosnians',
#  'appereantly',
#  'sensationalist',
#  'mafia',
#  'universial',
#  'cabal',
#  'mysore',
#  'ownership',
#  'helpfuls',
#  'spartan',
#  'comraderie',
#  'pialat',
#  'vv',
#  'arminian',
#  'spitied',
#  'conniption',
#  'emmannuelle',
#  'nachtmusik',
#  'crashing',
#  'strongpoints',
#  'opulence',
#  'statement',
#  'daneliucs',
#  'tampering',
#  'arisen',
#  'woebegone',
#  'scrape',
#  'cgiwhich',
#  'brilliantly',
#  'gentility',
#  'fractured',
#  'stassard',
#  'croons',
#  'jumpedtheshark',
#  'compensations',
#  'dodgy',
#  'lifelong',
#  'thre',
#  'blackmailing',
#  'plumber',
#  'armor',
#  'puss',
#  'chant',
#  'nellie',
#  'voorhess',
#  'watterman',
#  'motorbikes',
#  'daslow',
#  'unbreakable',
#  'labourer',
#  'solondz',
#  'beer',
#  'ladykillers',
#  'binoche',
#  'scarecreow',
#  'villaronga',
#  'pelting',
#  'lol',
#  'cannabalistic',
#  'ball',
#  'ruffled',
#  'mercenary',
#  'glovers',
#  'bungy',
#  'alladin',
#  'steerage',
#  'offenders',
#  'hamm',
#  'windmills',
#  'autre',
#  'hooligan',
#  'mote',
#  'fiving',
#  'unbuckles',
#  'lipsticked',
#  'perversity',
#  'wopat',
#  'hogie',
#  'idealology',
#  'undergone',
#  'symbolize',
#  'filmrolls',
#  'agonized',
#  'gon',
#  'firetrap',
#  'harper',
#  'reforms',
#  'evening',
#  'discerned',
#  'surnamed',
#  'mounting',
#  'obnoxious',
#  'bothersome',
#  'electrifyingly',
#  'songmaking',
#  'elusiveness',
#  'dominque',
#  'brands',
#  'criminologist',
#  'turquistan',
#  'mesmeric',
#  'teensploitation',
#  'coiffure',
#  'twelve',
#  'jive',
#  'kindegarden',
#  'lrner',
#  'avalanche',
#  'wooh',
#  'balled',
#  'sebastian',
#  'ferocious',
#  'blandest',
#  'assassain',
#  'jampacked',
#  'zag',
#  'interface',
#  'gutenberg',
#  'endor',
#  'parrot',
#  'hays',
#  'ironed',
#  'expertise',
#  'sabella',
#  'flynnish',
#  'attonment',
#  'unanimousness',
#  'glumly',
#  'pitzalis',
#  'natwick',
#  'impetuous',
#  'handedness',
#  'genova',
#  'agatha',
#  'distributing',
#  'thermostat',
#  'adventist',
#  'league',
#  'aha',
#  'fitting',
#  'multiethnical',
#  'bonita',
#  'fearful',
#  'hatted',
#  'info',
#  'gulping',
#  'yanno',
#  'okuhara',
#  'dispersement',
#  'minna',
#  'memory',
#  'quibbling',
#  'greg',
#  'sleeveless',
#  'social',
#  'nutjobseen',
#  'lorica',
#  'sainthood',
#  'rempit',
#  'fastforward',
#  'estrange',
#  'innovating',
#  'unbowed',
#  'time',
#  'blackmailed',
#  'kappa',
#  'repayed',
#  'contractual',
#  'toulouse',
#  'filmically',
#  'gogo',
#  'repelling',
#  'honestly',
#  'sanitizes',
#  'feminist',
#  'apron',
#  'bittorrent',
#  'seniority',
#  'cumparsita',
#  'judd',
#  'buyer',
#  'braggart',
#  'blom',
#  'cobern',
#  'commercisliation',
#  'poppa',
#  'carto',
#  'flutters',
#  'overly',
#  'hobart',
#  'faltermeyer',
#  'seseme',
#  'oafs',
#  'playthings',
#  'adr',
#  'zaniness',
#  'feared',
#  'sequitur',
#  'narration',
#  'bhoomika',
#  'germaine',
#  'vaporising',
#  'solutions',
#  'bllsosopher',
#  'haje',
#  'stearns',
#  'hauteur',
#  'taxpayers',
#  'motoring',
#  'presence',
#  'nipar',
#  'factors',
#  'hyodo',
#  'stymie',
#  'salton',
#  'thorp',
#  'antonius',
#  'jutras',
#  'yelchin',
#  'ce',
#  'scouts',
#  'chabrol',
#  'woody',
#  'rashomon',
#  'cyrano',
#  'conferences',
#  'poly',
#  'amita',
#  'sycophant',
#  'indicating',
#  'escaped',
#  'bizarrely',
#  'payed',
#  'halleck',
#  'planetoids',
#  'herbut',
#  'represented',
#  'apallingly',
#  'hellbreeder',
#  'beepingmary',
#  'subzero',
#  'snarls',
#  'stripclub',
#  'coleen',
#  'partnering',
#  'shears',
#  'mendacious',
#  'plagiary',
#  'literates',
#  'delinquent',
#  'resistible',
#  'aviation',
#  'knox',
#  'kasugi',
#  'subdivisions',
#  'anderson',
#  'whately',
#  'endowment',
#  'mariette',
#  'gottowt',
#  'reproductive',
#  'quirkiness',
#  'reincarnation',
#  'paige',
#  'shriners',
#  'edyarb',
#  'gainey',
#  'fightfest',
#  'rollo',
#  'criminology',
#  'kuan',
#  'dante',
#  'ohhh',
#  'quibble',
#  'irksome',
#  'stateliness',
#  'unswerving',
#  'celebritie',
#  'incident',
#  'torpidly',
#  'handsomest',
#  'eeeekkk',
#  'emphasised',
#  'philosophic',
#  'conjunctivitis',
#  'bookstore',
#  'mardi',
#  'perverseness',
#  'distributer',
#  'whistlestop',
#  'tennyson',
#  'offhand',
#  'plump',
#  'shogunate',
#  'jasons',
#  'abner',
#  'dey',
#  'nikolaj',
#  'outdoing',
#  'cushions',
#  'revise',
#  'misogamist',
#  'incongruent',
#  'altagracia',
#  'festival',
#  'entity',
#  'riscorla',
#  'infer',
#  'fop',
#  'eskimo',
#  'wrongheaded',
#  'bazookas',
#  'repertoire',
#  'resources',
#  'bugundian',
#  'claimer',
#  'wembley',
#  'posture',
#  'nighty',
#  'sleepwalking',
#  'moran',
#  'feisty',
#  'loups',
#  'harangued',
#  'unrespecting',
#  'zink',
#  'cannibalized',
#  'bustiers',
#  'weak',
#  'pedophile',
#  'defecates',
#  'graffiti',
#  'spouses',
#  'masterfully',
#  'brood',
#  'tweaked',
#  'museums',
#  'mbongeni',
#  'volita',
#  'aristocrat',
#  'ness',
#  'blag',
#  'outragously',
#  'overtones',
#  'reinstate',
#  'construe',
#  'napton',
#  'somos',
#  'unperturbed',
#  'scrambles',
#  'genies',
#  'magnetism',
#  'shea',
#  'railways',
#  'enraging',
#  'otaku',
#  'underlays',
#  'illustrated',
#  'cherubs',
#  'chuckawalla',
#  'palatir',
#  'boran',
#  'occastional',
#  'ogres',
#  'sheepskin',
#  'rasputin',
#  'leanne',
#  'receives',
#  'carted',
#  'disrespecting',
#  'brothel',
#  'lisbeth',
#  'egotistical',
#  'parched',
#  'dignify',
#  'bowlers',
#  'yancy',
#  'commending',
#  'illusion',
#  'beaubian',
#  'shaffner',
#  'mantelpiece',
#  'caas',
#  'worldliness',
#  'vinessa',
#  'dahlia',
#  'higherpraise',
#  'tester',
#  'pothole',
#  'aaah',
#  'blackwoods',
#  'veal',
#  'civilizations',
#  'uncannily',
#  'cem',
#  'slapchop',
#  'jigoku',
#  'treaties',
#  'pilger',
#  'rewarded',
#  'brakes',
#  'mie',
#  'duilio',
#  'soll',
#  'hues',
#  'aquilae',
#  'masacism',
#  'leia',
#  'centurians',
#  'villain',
#  'connotations',
#  'marchal',
#  'lamplight',
#  'affable',
#  'subverts',
#  'tane',
#  'afore',
#  'speakman',
#  'drohkaal',
#  'wheeling',
#  'bog',
#  'viy',
#  'warming',
#  'coherency',
#  'whalin',
#  'mcg',
#  'unstoppable',
#  'sontee',
#  'feeds',
#  'bhandarkar',
#  'sikhs',
#  'michaelangelo',
#  'dakar',
#  'jurassic',
#  'peva',
#  'sue',
#  'russians',
#  'tribbles',
#  'sauntered',
#  'similarities',
#  'marionettes',
#  'rash',
#  'teer',
#  'knoxville',
#  'husbands',
#  'anglicised',
#  'pascale',
#  'debit',
#  'unconventionality',
#  'unenviable',
#  'unlikely',
#  'cordobes',
#  'alienates',
#  'inventive',
#  'striped',
#  'johnathan',
#  'slimmed',
#  'deeds',
#  'grinded',
#  'tapes',
#  'mulan',
#  'honourable',
#  'meyer',
#  'infomercials',
#  'involve',
#  'wasteland',
#  'bastardized',
#  'formalist',
#  'karyn',
#  'reactionary',
#  'masterbates',
#  'sightedness',
#  'hopkirk',
#  'boobtube',
#  'sceptic',
#  'virology',
#  'apologize',
#  'corroborration',
#  'zuckerman',
#  'billions',
#  'ventresca',
#  'edgier',
#  'santa',
#  'greeter',
#  'liv',
#  'ignited',
#  'brawled',
#  'bearbado',
#  'forego',
#  'deferent',
#  'dependency',
#  'gotta',
#  'dividend',
#  'championship',
#  'bonneville',
#  'autographed',
#  'continually',
#  'beban',
#  'abbotcostello',
#  'broadcasters',
#  'sanufu',
#  'riker',
#  'guinneapig',
#  'dialed',
#  'sideburns',
#  'okey',
#  'zoimbies',
#  'loews',
#  'tersteeghe',
#  'roamed',
#  'resolution',
#  'quivvles',
#  'primitiveness',
#  'taurus',
#  'shep',
#  'aby',
#  'rattlesnakes',
#  'intriguingly',
#  'recreational',
#  'paralleling',
#  'kamikaze',
#  'soiree',
#  'vh',
#  'cornerstones',
#  'heave',
#  'ruskin',
#  'brilliantine',
#  'vainly',
#  'und',
#  'jmv',
#  'crimelord',
#  'frencified',
#  'hollowness',
#  'bandaras',
#  'milking',
#  'levee',
#  'gatsby',
#  'thinking',
#  'melange',
#  'momentarily',
#  'teat',
#  'sonic',
#  'caddy',
#  'reference',
#  'nana',
#  'enhancements',
#  'bluntness',
#  'rickman',
#  'bedeviled',
#  'ryoma',
#  'naya',
#  'unobservant',
#  'pittman',
#  'seymour',
#  'upruptly',
#  'mallet',
#  'subspace',
#  'enticingly',
#  'sight',
#  'swng',
#  'medically',
#  'lowell',
#  'ain',
#  'clementine',
#  'heorine',
#  'munched',
#  'paddles',
#  'timeless',
#  'thang',
#  'unforssen',
#  'spokesmen',
#  'jealousies',
#  'obligingly',
#  'tactical',
#  'attempting',
#  'unkempt',
#  'cinematographicly',
#  'hepcats',
#  'sabertooth',
#  'deliberately',
#  'prominance',
#  'dispersion',
#  'popping',
#  'aw',
#  'bulldozer',
#  'dorms',
#  'chennai',
#  'bhumika',
#  'crinolines',
#  'infuriates',
#  'goddess',
#  'tingles',
#  'sophia',
#  'bathes',
#  'swaps',
#  'gravedancers',
#  'acrobatics',
#  'colon',
#  'slash',
#  'unexpectedness',
#  'disguising',
#  'flashier',
#  'hasty',
#  'selve',
#  'callousness',
#  'borderick',
#  'exteriorizing',
#  'imbecility',
#  'moody',
#  'quotidian',
#  'mysticism',
#  'flung',
#  'nyman',
#  'foretaste',
#  'tashy',
#  'historic',
#  'baptises',
#  'judas',
#  'wathced',
#  'slay',
#  'silence',
#  'lasalle',
#  'confound',
#  'teru',
#  'shillabeer',
#  'westernized',
#  'eduction',
#  'despairs',
#  'kia',
#  'mourikis',
#  'lessons',
#  'napunsaktha',
#  'corsia',
#  'exile',
#  'revile',
#  'smarmy',
#  'rathbone',
#  'yager',
#  'hearse',
#  'dumann',
#  'resourceful',
#  'gauche',
#  'hyung',
#  'slayride',
#  'sexo',
#  'xo',
#  'loosey',
#  'poxy',
#  'arminass',
#  'baloons',
#  'descent',
#  'spice',
#  'looming',
#  'rituals',
#  'russel',
#  'chauffers',
#  'allotting',
#  'additive',
#  'beleiving',
#  'fending',
#  'belleville',
#  'rummage',
#  'superpowerman',
#  'yearning',
#  'farmiga',
#  'bereft',
#  'turkic',
#  'regulated',
#  'especialmente',
#  'empowerment',
#  'brutalities',
#  'adrenaline',
#  'chainsaw',
#  'moonchild',
#  'netlesk',
#  'galley',
#  'talkier',
#  'rakastin',
#  'exceeded',
#  'antonella',
#  'eyow',
#  'muddling',
#  'reconcile',
#  'ecuador',
#  'searches',
#  'mellower',
#  'spruced',
#  'littttle',
#  'scrunching',
#  'flashbacked',
#  'hogs',
#  'muro',
#  'talk',
#  'yorick',
#  'screws',
#  'kay',
#  'inferior',
#  'stomaches',
#  'witchblade',
#  'fumble',
#  'unfettered',
#  'rotorscoped',
#  'cylinder',
#  'edges',
#  'geraldo',
#  'embarassing',
#  'trattoria',
#  'gilding',
#  'elizondo',
#  'yochobel',
#  'fontainey',
#  'works',
#  'rh',
#  'risking',
#  'nuys',
#  'mouthburster',
#  'ivor',
#  'paperback',
#  'sudio',
#  'ventured',
#  'vagrant',
#  'seda',
#  'lacing',
#  'rentar',
#  'camillo',
#  'ahlan',
#  'thunderstorm',
#  'penniless',
#  'meighan',
#  'sportswriter',
#  'sagal',
#  'kristopherson',
#  'alives',
#  'pluses',
#  'columns',
#  'kazuma',
#  'champagne',
#  'wookie',
#  'flamingos',
#  'paean',
#  'cartouche',
#  'farted',
#  'albertson',
#  'swooning',
#  'deity',
#  'wrest',
#  'insanity',
#  'viscontis',
#  'overplaying',
#  'duchaussoy',
#  'bhatt',
#  'robotics',
#  'mylo',
#  'dinners',
#  'cereals',
#  'presenting',
#  'beatings',
#  'deus',
#  'clashes',
#  'everpresent',
#  'toad',
#  'stetner',
#  'littlest',
#  'shyamalan',
#  'devadharshini',
#  'pseudo',
#  'polynesia',
#  'machinas',
#  'musicals',
#  'stratified',
#  'attentiontisserand',
#  'names',
#  'annemarie',
#  'faithfully',
#  'ballets',
#  'vinny',
#  'chief',
#  'vashti',
#  'asswipe',
#  'ey',
#  'vaudeville',
#  'yitzhack',
#  'soldierthe',
#  'completly',
#  'zeroness',
#  'shape',
#  'chattel',
#  'shafeek',
#  'famarialy',
#  'quatermain',
#  'stalking',
#  'citadel',
#  'doestoevisky',
#  'administering',
#  'payal',
#  'galens',
#  'gentle',
#  'jostling',
#  'debunks',
#  'nyc',
#  'scintillating',
#  'broiler',
#  'peoria',
#  'jelaousy',
#  'advantageous',
#  'stefanovic',
#  'rolaids',
#  'toothbrushes',
#  'malaysian',
#  'embody',
#  'wiggling',
#  'elmann',
#  'eagerly',
#  'mater',
#  'billy',
#  'retentive',
#  'dion',
#  'daddies',
#  'scooter',
#  'tenet',
#  'portastatic',
#  'fabrizio',
#  'mystifyingly',
#  'chittering',
#  'complained',
#  'majd',
#  'critially',
#  'schramm',
#  'nannies',
#  'tournier',
#  'adjust',
#  'allnut',
#  'horor',
#  'coulouris',
#  'kingly',
#  'rock',
#  'townies',
#  'gunghroo',
#  'fx',
#  'gelb',
#  'gordano',
#  'fry',
#  'excellence',
#  'wincibly',
#  'ticklish',
#  'trumpeter',
#  'banana',
#  'boringus',
#  'conventionally',
#  'satanism',
#  'filo',
#  'ringers',
#  'anupamji',
#  'antowne',
#  'roth',
#  'rubble',
#  'josephus',
#  'exercised',
#  'rustle',
#  'lyoko',
#  'slighter',
#  'sexagenarians',
#  'personification',
#  'ingmar',
#  'valid',
#  'toren',
#  'aavjo',
#  'propose',
#  'dudes',
#  'hodge',
#  'riviere',
#  'colloquialisms',
#  'venoms',
#  'barabarian',
#  'ngoyen',
#  'reviczky',
#  'tolmekians',
#  'blockbuster',
#  'schneerbaum',
#  'dowager',
#  'kensit',
#  'lazarus',
#  'heffner',
#  'montecito',
#  'commendations',
#  'reinhold',
#  'disenchantment',
#  'wasteful',
#  'garbagemen',
#  'jhene',
#  'phantasmogoric',
#  'lindsay',
#  'dyptic',
#  'greystone',
#  'skerritt',
#  'esperance',
#  'elam',
#  'zoos',
#  'knuckleheads',
#  'wolfie',
#  'porn',
#  'reclaiming',
#  'cooking',
#  'undertakers',
#  'dixit',
#  'yaayyyyy',
#  'schanzer',
#  'bestwithout',
#  'mussed',
#  'kashakim',
#  'prosper',
#  'hoofer',
#  'slaked',
#  'painted',
#  'believably',
#  'bookend',
#  'prisinors',
#  'nnette',
#  'dramatism',
#  'zim',
#  'grody',
#  'caring',
#  ...]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file

p=figure()

source = ColumnDataSource(data=dict(x1=tsne2d[:,0],
                                    x2=tsne2d[:,1],
                                    names=list(ml.word2index.keys())))

p.scatter(x="x1", y="x2", size=8, source=source)

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#111000",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)
