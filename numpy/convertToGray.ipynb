# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = plt.imread("./assets/cheetah.jpg")
plt.imshow(img)
plt.show()
img.shape
# Out:
# (549, 976, 3)

# %%
def convertToGray(img):
    return (0.212*img[:,:,0]+0.701*img[:,:,1]+0.087*img[:,:,2])/225.0
Image.open("./assets/luma.PNG")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=814x257 at 0x1F19B9008B0>

# %%
plt.imshow(convertToGray(img),cmap="gray")
plt.show()
